# %% [markdown]
# ##Install addition Python enviornment

# %% [markdown]
# ### Install Python 3

# %%
# !conda create -y -n python3 python=3.4 anaconda
# Out:
# Fetching package metadata: ....
# Solving package specifications: .
# Package plan for installation in environment /Users/DicksonK/anaconda/envs/python3:
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jbig-2.1                   |                0          31 KB
#     mkl-11.3.1                 |                0        99.1 MB
#     openssl-1.0.2f             |                0         3.0 MB
#     sqlite-3.9.2               |                0         1.2 MB
#     xz-5.0.5                   |                0         132 KB
#     zeromq-4.1.3               |                0         577 KB
#     curl-7.45.0                |                0         371 KB
#     freetype-2.5.5             |                0         732 KB
#     hdf5-1.8.15.1              |                2         1.6 MB
#     libtiff-4.0.6              |                1         736 KB
# ...

# %% [markdown]
# ```
#     #
#     # To activate this environment, use:
#     # $ source activate python3
#     #
#     # To deactivate this environment, use:
#     # $ source deactivate
# ```

# %% [markdown]
# Stop the VM
#
# Update your VagrantFile
#
# Add a line:
# ```
# config.vm.network "forwarded_port", guest: 8889, host: 8889
# ```
#
# Restart your VM

# %% [markdown]
# Run the following in your VM terminal:
# ```
# source activate python3
# pip install brunel
# ipython notebook
# ```

# %%
print 'hello world'
# Out:
# hello world

# %%
from __future__ import print_function

# %%
print('hello world')
# Out:
# hello world
